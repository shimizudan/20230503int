# %%
1+1
# Out:
# 2

# %%
Integrate[(1+x^2)x ArcTan[x]/(2+x^2)^(5/2),{x,0,1}]//TraditionalForm
# Out:
# FormBox[RowBox[{FractionBox["1", "54"], " ",
#
#
# >        RowBox[{"(", RowBox[{RowBox[{"3", " ", SqrtBox["3"]}], "+",
#
#
# >            RowBox[{RowBox[{"(", RowBox[{"6", "-", RowBox[{"4", " ", SqrtBox["3"]}]}],
#
#
# >                ")"}], " ", "π"}]}], ")"}]}], TraditionalForm]

# %%
Integrate[x Sin[x]/(1+Cos[x]^2)^(5/2),{x,0,Pi/4}]//TraditionalForm
# Out:
# FormBox[RowBox[{FractionBox["1", "54"], " ",
#
#
# >        RowBox[{"(", RowBox[{RowBox[{"3", " ", SqrtBox["3"]}], "+",
#
#
# >            RowBox[{RowBox[{"(", RowBox[{"6", "-", RowBox[{"4", " ", SqrtBox["3"]}]}],
#
#
# >                ")"}], " ", "π"}]}], ")"}]}], TraditionalForm]

# %%
Plot3D[Sin[x*y],{x,0,2 Pi},{y,0,2 Pi}]
# Out:
# -Graphics3D-
